# %%
import numpy as np
import matplotlib.pyplot as plt

npy_file_path = '/home/ubuntu/mask_randbg_tool/images/output/img0_mask.npy'
segmentation_mask = np.load(npy_file_path)

plt.figure(figsize=(10, 10))
plt.imshow(segmentation_mask, cmap='gray')
plt.axis('off')
plt.show()
